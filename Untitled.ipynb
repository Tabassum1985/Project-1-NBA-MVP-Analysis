# %%
import pandas as pd
import numpy as np
import os
# path_imput = os.path.join("NBA_Finals_and_MVP.xlsx")
# df = pd.read_excel(path_imput)
draft_df = pd.read_excel('file://localhost/Users/mitchellboullt/Project-1/Resources /NBA Drafts.xlsx')
draft_df
mvp = pd.read_excel('new_folder/NBA_Finals_and_MVP.xlsx')

# %%
mvp = mvp.tail(30)
mvp
# Out:
#     Year        Western Champion     Eastern Champion Result  \
# 39  1989      Los Angeles Lakers      Detroit Pistons    0–4
# 40  1990  Portland Trail Blazers      Detroit Pistons    1–4
# 41  1991      Los Angeles Lakers        Chicago Bulls    1–4
# 42  1992  Portland Trail Blazers        Chicago Bulls    2–4
# 43  1993            Phoenix Suns        Chicago Bulls    2–4
# 44  1994         Houston Rockets      New York Knicks    4–3
# 45  1995         Houston Rockets        Orlando Magic    4–0
# 46  1996     Seattle SuperSonics        Chicago Bulls    2–4
# 47  1997               Utah Jazz        Chicago Bulls    2–4
# 48  1998               Utah Jazz        Chicago Bulls    2–4
# 49  1999       San Antonio Spurs      New York Knicks    4–1
# 50  2000      Los Angeles Lakers       Indiana Pacers    4–2
# 51  2001      Los Angeles Lakers   Philadelphia 76ers    4–1
# 52  2002      Los Angeles Lakers      New Jersey Nets    4–0
# ...

# %%
pd.merge(mvp, total_picks, on="Year")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/3k/6xzjh8pd05z3pk2qlf50c_b80000gn/T/ipykernel_74147/2820410210.py in <module>
# ----> 1 pd.merge(mvp, total_picks, on="Year")
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     666             self.right_join_keys,
#     667             self.join_names,
# ...

# %%
total_picks = draft_df.groupby(['Draft Year','Team']).count()['Pick']

# %%
total_picks = pd.DataFrame(total_picks)
total_picks
# Out:
#                  Pick
# Draft Year Team
# 1989       ATL      2
#            BOS      2
#            CHH      2
#            CHI      3
#            CLE      2
# ...               ...
# 2016       PHO      4
#            SAC      2
#            SAS      1
#            TOR      2
#            UTA      4
#
# [768 rows x 1 columns]

# %%
cities_df = pd.read_json('Resources /case1.json')
cities_df['seasons']
cities_df
# Out:
#                  key                                             values  \
# 0      Green Bay, WI  [{'year': 1929, 'team': 'Green Bay Packers', '...
# 1         Sarnia, ON  [{'year': 1934, 'team': 'Sarnia Imperials', 's...
# 2       Hamilton, ON  [{'year': 1912, 'team': 'Hamilton Alerts', 'sp...
# 3         Regina, SK  [{'year': 1966, 'team': 'Saskatchewan Roughrid...
# 4       Edmonton, AB  [{'year': 1954, 'team': 'Edmonton Eskimos', 's...
# ..               ...                                                ...
# 313     Harrison, NY                                                 []
# 314  Orange City, IA                                                 []
# 315      Bolivar, MO                                                 []
# 316   Kirksville, MO                                                 []
# 317  Valley City, ND                                                 []
#
#      population                                            seasons
# ...

# %%
boston = cities_df['values'][8]

# %%
toronto = cities_df['values'][10]

# %%
dertroit = cities_df['values'][12]
